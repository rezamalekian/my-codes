# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/DL_projects_colab/yolov8/'

# %%
# %cd {ROOT_DIR}
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/DL_projects_colab/yolov8/'
# /content

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 35616, done.
# remote: Counting objects: 100% (4193/4193), done.
# remote: Compressing objects: 100% (1818/1818), done.
# remote: Total 35616 (delta 2896), reused 3498 (delta 2355), pack-reused 31423
# Receiving objects: 100% (35616/35616), 29.68 MiB | 17.51 MiB/s, done.
# Resolving deltas: 100% (25686/25686), done.
# /content/ultralytics

# %%
# %cd /content/ultralytics
# Out:
# /content/ultralytics

# %%
# !git pull
# Out:
# Already up to date.

# %%
# %ls
# Out:
# CITATION.cff     docker/  examples/  mkdocs.yml      README.md        tests/
# CONTRIBUTING.md  docs/    LICENSE    pyproject.toml  README.zh-CN.md  ultralytics/

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
# !pip install ultralytics

# %%
# %cd {ROOT_DIR}
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/DL_projects_colab/yolov8/'
# /content/ultralytics

# %%
# !pip install Ipython
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...

# %%
import matplotlib.pyplot as plt
from IPython.display import Image as imgshow
import os

# %%
# !yolo task=detect mode=predict model=yolov8x.pt conf=0.2 source="/content/dogs_n_cars.jpg" save=True
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# image 1/1 /content/dogs_n_cars.jpg: 448x640 4 cars, 2 trucks, 8 dogs, 4 sheeps, 117.1ms
# Speed: 2.9ms preprocess, 117.1ms inference, 541.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/ultralytics/runs/detect/predict11
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
imgshow(os.path.join(ROOT_DIR,"/content/ultralytics/runs/detect/predict11/dogs_n_cars.jpg"), width = 600)

# %%
# !yolo task=detect mode=predict model=yolov8x.pt conf=0.25 source="/content/test_vid.mp4" save=True
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# video 1/1 (frame 1/240) /content/test_vid.mp4: 384x640 1 truck, 3 sheeps, 118.0ms
# video 1/1 (frame 2/240) /content/test_vid.mp4: 384x640 1 truck, 3 sheeps, 51.8ms
# video 1/1 (frame 3/240) /content/test_vid.mp4: 384x640 1 truck, 51.1ms
# video 1/1 (frame 4/240) /content/test_vid.mp4: 384x640 1 truck, 2 sheeps, 50.1ms
# video 1/1 (frame 5/240) /content/test_vid.mp4: 384x640 1 truck, 3 sheeps, 50.0ms
# video 1/1 (frame 6/240) /content/test_vid.mp4: 384x640 1 truck, 2 sheeps, 50.0ms
# video 1/1 (frame 7/240) /content/test_vid.mp4: 384x640 1 truck, 1 dog, 1 sheep, 34.5ms
# video 1/1 (frame 8/240) /content/test_vid.mp4: 384x640 1 car, 1 truck, 1 dog, 32.8ms
# video 1/1 (frame 9/240) /content/test_vid.mp4: 384x640 2 trucks, 1 dog, 32.8ms
# video 1/1 (frame 10/240) /content/test_vid.mp4: 384x640 1 truck, 33.0ms
# ...

# %%
# !yolo task=segment mode=predict model='yolov8x-seg.pt' conf=0.25 source="/content/dogs_n_cars.jpg" save=True
# Out:
# ...
# 100% 137M/137M [00:03<00:00, 40.1MB/s]
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71,797,696 parameters, 0 gradients, 344.1 GFLOPs
#
# image 1/1 /content/dogs_n_cars.jpg: 448x640 4 cars, 2 trucks, 8 dogs, 121.9ms
# Speed: 3.1ms preprocess, 121.9ms inference, 689.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/ultralytics/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
imgshow(os.path.join(ROOT_DIR,'/content/ultralytics/runs/segment/predict/dogs_n_cars.jpg'), width = 600)

# %%
# !yolo task=segment mode=predict conf=0.25 source="/content/test_vid.mp4" save=True
# Out:
# ...
# 100% 6.74M/6.74M [00:00<00:00, 396MB/s]
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# video 1/1 (frame 1/240) /content/test_vid.mp4: 384x640 1 truck, 3 cows, 138.0ms
# video 1/1 (frame 2/240) /content/test_vid.mp4: 384x640 1 truck, 2 cows, 8.2ms
# video 1/1 (frame 3/240) /content/test_vid.mp4: 384x640 2 trucks, 7.8ms
# video 1/1 (frame 4/240) /content/test_vid.mp4: 384x640 2 trucks, 1 horse, 1 cow, 7.7ms
# video 1/1 (frame 5/240) /content/test_vid.mp4: 384x640 2 trucks, 1 horse, 7.7ms
# video 1/1 (frame 6/240) /content/test_vid.mp4: 384x640 2 trucks, 7.9ms
# video 1/1 (frame 7/240) /content/test_vid.mp4: 384x640 1 truck, 1 horse, 1 chair, 7.8ms
# video 1/1 (frame 8/240) /content/test_vid.mp4: 384x640 1 truck, 7.9ms
# video 1/1 (frame 9/240) /content/test_vid.mp4: 384x640 2 trucks, 1 horse, 1 cow, 7.7ms
# ...
